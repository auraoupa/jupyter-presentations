# %% [markdown]
# <table width="100%" style="border: none;">
# <tr style="border: none;">
# <td width="100px" style="border: none;"><img width="100" src="logo-git.png"></img></td>
# <td width="50%" style="border: none"> </td>
# <td width="200px" style="border: none;">
# <img width="200" src="github.png"></img>
# </td>
# </table>
#
# # Git basic commands and github usage
#
# ## By A. Albert

# %% [markdown]
# <table width="100%" style="border: none;">
# <tr style="border: none;">
# <td width="100px" style="border: none;"><img width="100" src="logo-git.png"></img></td>
# <td width="50%" style="border: none"> </td>
# <td width="200px" style="border: none;">
# </td>
# </table>
#
# # Why use a version control system ?
#
# - for collaborative work (ex: NEMO, CDFTOOLS, oocgcm, MEOM website)
# - for personnal work : accessibility from any machine, keeping tracks of modifications (ex: JLS notebools, presentations, scripts, etc ...)

# %% [markdown]
# <table width="100%" style="border: none;">
# <tr style="border: none;">
# <td width="100px" style="border: none;"><img width="100" src="logo-git.png"></img></td>
# <td width="50%" style="border: none"> </td>
# <td width="200px" style="border: none;">
# </td>
# </table>
#
# # Specificity of git
#
# - snpashots instead of file-based changes
# - distributed instead of centralized
# - we can keep everything local (=offline)
# - 3 states of files : modified, staged, commited

# %% [markdown]
# <table width="100%" style="border: none;">
# <tr style="border: none;">
# <td width="100px" style="border: none;"><img width="100" src="logo-git.png"></img></td>
# <td width="50%" style="border: none"> </td>
# <td width="200px" style="border: none;">
# </td>
# </table>
#
# ![stagging area](https://git-scm.com/images/about/index1@2x.png)

# %% [markdown]
# <table width="100%" style="border: none;">
# <tr style="border: none;">
# <td width="100px" style="border: none;"><img width="100" src="logo-git.png"></img></td>
# <td width="50%" style="border: none"> </td>
# <td width="200px" style="border: none;">
# </td>
# </table>
#
# # Example 1 : transform a simple directory into a git repository

# %% [markdown]
# ![line of commands](ex1-1.png)

# %% [markdown]
# ![line of commands](ex1-2.png)

# %% [markdown]
# ![line of commands](ex1-3.png)

# %% [markdown]
# ![line of commands](ex1-4.png)

# %% [markdown]
# # Git commands
#
#     > git init
#     > git add *
#     > git commit -m "comment"
#     > git status
#     > git log

# %% [markdown]
# <table width="100%" style="border: none;">
# <tr style="border: none;">
# <td width="100px" style="border: none;"><img width="100" src="logo-git.png"></img></td>
# <td width="50%" style="border: none"> </td>
# <td width="200px" style="border: none;">
# </td>
# </table>
#
# # Example 2 : clone an existing repository

# %% [markdown]
# ![line of commands](ex2.png)

# %% [markdown]
# ![line of commands](ex2b-1.png)

# %% [markdown]
# ![line of commands](ex2b-2.png)

# %% [markdown]
# # Git commands
#
#     > git clone url
#     > git fetch
#     > git merge
#     > git pull = fetch + merge
#     > git push

# %% [markdown]
# <table width="100%" style="border: none;">
# <tr style="border: none;">
# <td width="100px" style="border: none;"><img width="100" src="logo-git.png"></img></td>
# <td width="50%" style="border: none"> </td>
# <td width="200px" style="border: none;">
# </td>
# </table>
#
# # Sources

# %% [markdown]
# - git-scm.com
#
# ![line of commands](gitscm_web.png)

# %% [markdown]
# - Progit book
#
# ![line of commands](progit.jpeg)

# %% [markdown]
# - Talk by S. Chacon
#
# [![Git video by S. Chacon](http://img.youtube.com/vi/ZDR433b0HJY/0.jpg)](https://www.youtube.com/watch?v=ZDR433b0HJY)

# %% [markdown]
# <table width="100%" style="border: none;">
# <tr style="border: none;">
# <td width="100px" style="border: none;"></td>
# <td width="50%" style="border: none"> </td>
# <td width="200px" style="border: none;">
# <img width="200" src="github.png"></img>
# </td>
# </table>
#
# # Github : a hosting site for git repositories

# %% [markdown]
# ![line of commands](github_page.png)

# %% [markdown]
# ![line of commands](github_auraoupa.png)

# %% [markdown]
# ![line of commands](github_meom.png)

# %% [markdown]
# ![line of commands](github_code.png)
